# %% [markdown]
#  <font size="6"> <b> Final Project : Suzi Ryu 991522132</b> </font>

# %% [markdown]
# <font size="3"> <b>Dataset</b> : Abalone <br>
# <b>Task</b> : Classification<br>
# <b>Target Value</b> : Sex<br> </font>

# %% [markdown]
#  <font size="5"> <b> * Getting the Data *</b> </font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data',names=["Sex","Length","Diameter","Height","Whole weight", "Shucked weight", "Viscera weight", "Shell weight", "Rings"],header = None)

df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
#check the shape of data
df.shape
# Out:
# (4177, 9)

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (3759, 9)
# Unseen Data For Predictions: (418, 9)

# %% [markdown]
# <font size="5"> <b> * Setting up Environment in PyCaret *</b> </font>

# %%
from pycaret.classification import *

abaloneData = setup(data = data, target = 'Sex', session_id=123)
# Out:
# <style  type="text/css" >
# #T_f30b7_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_f30b7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f30b7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f30b7_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f30b7_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_f30b7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f30b7_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_f30b7_row1_col1" class="data row1 col1" >Sex</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
#  <font size="5"> <b>* Comparing All Models *</b> </font>

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_e0b47_ th {
#           text-align: left;
# ...

# %% [markdown]
#  <font size="5"> <b>* Create a Model *</b> </font>

# %% [markdown]
#  <font size="4"> <b>1. Decision Tree Classifier</b> </font>

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_72f94_row10_col0,#T_72f94_row10_col1,#T_72f94_row10_col2,#T_72f94_row10_col3,#T_72f94_row10_col4,#T_72f94_row10_col5,#T_72f94_row10_col6{
#             background:  yellow;
#         }</style><table id="T_72f94_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72f94_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_72f94_row0_col0" class="data row0 col0" >0.5076</td>
# ...

# %%
#trained model object is stored in the variable 'dt'. 
print(dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %% [markdown]
#  <font size="4"> <b>2. K Neighbors Classifier</b> </font>

# %%
knn = create_model('knn')
# Out:
# <style  type="text/css" >
# #T_8694f_row10_col0,#T_8694f_row10_col1,#T_8694f_row10_col2,#T_8694f_row10_col3,#T_8694f_row10_col4,#T_8694f_row10_col5,#T_8694f_row10_col6{
#             background:  yellow;
#         }</style><table id="T_8694f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8694f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8694f_row0_col0" class="data row0 col0" >0.5189</td>
# ...

# %% [markdown]
#  <font size="4"> <b>3. Logistic Regression</b> </font>

# %%
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_a32ff_row10_col0,#T_a32ff_row10_col1,#T_a32ff_row10_col2,#T_a32ff_row10_col3,#T_a32ff_row10_col4,#T_a32ff_row10_col5,#T_a32ff_row10_col6{
#             background:  yellow;
#         }</style><table id="T_a32ff_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a32ff_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a32ff_row0_col0" class="data row0 col0" >0.5644</td>
# ...

# %% [markdown]
#  <font size="5"> <b>* Tune a Model *</b> </font>

# %% [markdown]
#  <font size="4"> <b>1. Decision Tree Classifier</b> </font>

# %%
tuned_dt = tune_model(dt)
# Out:
# <style  type="text/css" >
# #T_0b584_row10_col0,#T_0b584_row10_col1,#T_0b584_row10_col2,#T_0b584_row10_col3,#T_0b584_row10_col4,#T_0b584_row10_col5,#T_0b584_row10_col6{
#             background:  yellow;
#         }</style><table id="T_0b584_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b584_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b584_row0_col0" class="data row0 col0" >0.5038</td>
# ...

# %%
#tuned model object is stored in the variable 'tuned_dt'. 
print(tuned_dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0002, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %% [markdown]
#  <font size="4"> <b>2. K Neighbors Classifier</b> </font>

# %%
tuned_knn = tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,50,1)})
# Out:
# <style  type="text/css" >
# #T_b96f6_row10_col0,#T_b96f6_row10_col1,#T_b96f6_row10_col2,#T_b96f6_row10_col3,#T_b96f6_row10_col4,#T_b96f6_row10_col5,#T_b96f6_row10_col6{
#             background:  yellow;
#         }</style><table id="T_b96f6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b96f6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b96f6_row0_col0" class="data row0 col0" >0.5265</td>
# ...

# %% [markdown]
#  <font size="4"> <b>3. Logistic Regression</b> </font>

# %%
tuned_lr = tune_model(lr)
# Out:
# <style  type="text/css" >
# #T_9bb48_row10_col0,#T_9bb48_row10_col1,#T_9bb48_row10_col2,#T_9bb48_row10_col3,#T_9bb48_row10_col4,#T_9bb48_row10_col5,#T_9bb48_row10_col6{
#             background:  yellow;
#         }</style><table id="T_9bb48_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bb48_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9bb48_row0_col0" class="data row0 col0" >0.5795</td>
# ...

# %% [markdown]
# <font size="5"> <b>* Plot a Model *</b> </font>

# %% [markdown]
#  <font size="4"> <b>1. Confusion Matrix</b> </font>

# %%
plot_model(tuned_knn, plot = 'confusion_matrix')

# %% [markdown]
#  <font size="4"> <b>2. Classification Report</b> </font>

# %%
plot_model(tuned_knn, plot = 'class_report')

# %% [markdown]
#  <font size="4"> <b>3. Decision Boundary Plot</b> </font>

# %%
plot_model(tuned_knn, plot='boundary')

# %% [markdown]
#  <font size="4"> <b>4. Prediction Error Plot</b> </font>

# %%
plot_model(tuned_knn, plot = 'error')

# %%
evaluate_model(tuned_knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# <font size="5"> <b>* Predict on test / hold-out Sample *</b> </font>

# %%
predict_model(tuned_knn);
# Out:
# <style  type="text/css" >
# </style><table id="T_f5382_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5382_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f5382_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#                         <td id="T_f5382_row0_col1" class="data row0 col1" >0.5479</td>
#                         <td id="T_f5382_row0_col2" class="data row0 col2" >0.7423</td>
# ...

# %% [markdown]
# <font size="5"> <b>* Finalize Model for Deployment *</b> </font>

# %%
final_knn = finalize_model(tuned_knn)

# %%
#Final K Nearest Neighbour parameters for deployment
print(final_knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=33, p=2,
#                      weights='uniform')

# %% [markdown]
# <font size="5"> <b>* Predict on unseen data *</b> </font>

# %%
unseen_predictions = predict_model(final_knn, data=data_unseen)
unseen_predictions.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 1   M   0.430     0.350   0.110        0.4060          0.1675          0.0810
# 2   F   0.535     0.405   0.145        0.6845          0.2725          0.1710
# 3   M   0.365     0.295   0.080        0.2555          0.0970          0.0430
# 4   F   0.550     0.415   0.135        0.7635          0.3180          0.2100
#
#    Shell weight  Rings Label   Score
# 0         0.120      8     I  0.7879
# 1         0.135     10     F  0.4545
# 2         0.205     10     F  0.3939
# 3         0.100      7     I  0.9394
# 4         0.200      9     I  0.3636

# %% [markdown]
# <font size="5"> <b>* Saving the model *</b> </font>

# %%
save_model(final_knn,'Final KNN Model AbaloneS')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Sex',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy...
#                  ('fix_perfect', Remove_100(target='Sex')),
#                  ('clean_names', Clean_Colum_Names()),
# ...

# %% [markdown]
# <font size="5"> <b>* Loading the saved model *</b> </font>

# %%
saved_final_knn = load_model('Final KNN Model AbaloneS')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_knn, data=data_unseen)

# %%
new_prediction.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 1   M   0.430     0.350   0.110        0.4060          0.1675          0.0810
# 2   F   0.535     0.405   0.145        0.6845          0.2725          0.1710
# 3   M   0.365     0.295   0.080        0.2555          0.0970          0.0430
# 4   F   0.550     0.415   0.135        0.7635          0.3180          0.2100
#
#    Shell weight  Rings Label   Score
# 0         0.120      8     I  0.7879
# 1         0.135     10     F  0.4545
# 2         0.205     10     F  0.3939
# 3         0.100      7     I  0.9394
# 4         0.200      9     I  0.3636
